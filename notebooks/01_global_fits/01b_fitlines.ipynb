# %%
import matplotlib.pyplot as plt
import pandas as pd
plt.rcParams['text.usetex'] = True

# %%
colors_line = [(0.8941176470588236, 0.10196078431372549, 0.10980392156862745),
 (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),
 (0.30196078431372547, 0.6862745098039216, 0.2901960784313726),
 (0.596078431372549, 0.3058823529411765, 0.6392156862745098),
 (1.0, 0.4980392156862745, 0.0),
 (1.0, 1.0, 0.2),
 (0.6509803921568628, 0.33725490196078434, 0.1568627450980392),
 (0.9686274509803922, 0.5058823529411764, 0.7490196078431373),
 (0.6, 0.6, 0.6)]

# %%
import numpy as np

# %% [markdown]
# ## Scenario I

# %%
fitC_I = pd.read_csv('likelihoodC_scI.dat')
fitbl_I = pd.read_csv('likelihoodbl_scI.dat')
fitbq_I = pd.read_csv('likelihoodbq_scI.dat')

# %%
plt.plot(fitC_I['C'], -fitC_I['global'], c=colors_line[4], label='Global')
plt.plot(fitC_I['C'], -fitC_I['likelihood_rd_rds.yaml'], c=colors_line[1], label=r'$b\to c\ell\nu$')
plt.plot(fitC_I['C'], -fitC_I['likelihood_bqnunu.yaml'], c=colors_line[3], label=r'$b\to s\nu\bar{\nu}$')
plt.axhline(-np.max(fitC_I['global'])+3.53/2, c='k', ls='--')
plt.axvline(-0.11, c='k', ls='--')
plt.axvline(-0.08, c='k', ls='--')
plt.axvline(-0.15, c='k', ls='--')
plt.ylim(-25, 20)
plt.xlim(-0.3, 0)
plt.xlabel(r'$C$', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel(r'$-\Delta \log L$', fontsize=20)
plt.legend(fontsize=16)
plt.tight_layout(pad=0.5)
#plt.savefig('likelihood_C1.pdf')

# %%
plt.plot(fitbl_I['bl'], -fitbl_I['global'], c=colors_line[4], label='Global')
plt.plot(fitbl_I['bl'], -fitbl_I['likelihood_rd_rds.yaml'], c=colors_line[1], label=r'$b\to c\ell\nu$')
plt.plot(fitbl_I['bl'], -fitbl_I['likelihood_bqnunu.yaml'], c=colors_line[3], label=r'$b\to s\nu\bar{\nu}$')
plt.axhline(-np.max(fitbl_I['global'])+3.53/2, c='k', ls='--')
#plt.axvline(-0.11, c='k', ls='--')
#plt.axvline(-0.08, c='k', ls='--')
#plt.axvline(-0.15, c='k', ls='--')
plt.ylim(-25, 20)
#plt.xlim(-0.3, 0)
plt.xlabel(r'$\beta^\ell$', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel(r'$-\Delta \log L$', fontsize=20)
plt.legend(fontsize=16)
plt.tight_layout(pad=0.5)

# %%
plt.plot(fitbq_I['bq'], -fitbq_I['global'], c=colors_line[4], label='Global')
plt.plot(fitbq_I['bq'], -fitbq_I['likelihood_rd_rds.yaml'], c=colors_line[1], label=r'$b\to c\ell\nu$')
plt.plot(fitbq_I['bq'], -fitbq_I['likelihood_bqnunu.yaml'], c=colors_line[3], label=r'$b\to s\nu\bar{\nu}$')
plt.axhline(-np.max(fitbq_I['global'])+3.53/2, c='k', ls='--')
plt.axvline(0.78, c='k', ls='--')
plt.axvline(0.42, c='k', ls='--')
plt.axvline(2.0, c='k', ls='--')
plt.ylim(-25, 20)
#plt.xlim(-0.3, 0)
plt.xlabel(r'$\beta^q$', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel(r'$-\Delta \log L$', fontsize=20)
plt.legend(fontsize=16)
plt.tight_layout(pad=0.5)

# %% [markdown]
# ## Scenario II

# %%
fitC_II = pd.read_csv('likelihoodC_scII.dat')
fital_II = pd.read_csv('likelihoodal_scII.dat')
fitaq_II = pd.read_csv('likelihoodaq_scII.dat')
fitbl_II = pd.read_csv('likelihoodbl_scII.dat')
fitbq_II = pd.read_csv('likelihoodbq_scII.dat')

# %%
plt.plot(fitC_II['C'], -fitC_II['global'], c=colors_line[4], label='Global')
plt.plot(fitC_II['C'], -fitC_II['likelihood_rd_rds.yaml'], c=colors_line[1], label=r'$b\to c\ell\nu$')
plt.plot(fitC_II['C'], -fitC_II['likelihood_bqnunu.yaml'], c=colors_line[3], label=r'$b\to s\nu\bar{\nu}$')
plt.axhline(-np.max(fitC_II['global'])+3.53/2, c='k', ls='--')
plt.axvline(-0.12, c='k', ls='--')
plt.axvline(-0.08, c='k', ls='--')
plt.axvline(-0.15, c='k', ls='--')
plt.ylim(-25, 20)
plt.xlim(-0.3, 0)
plt.xlabel(r'$C$', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel(r'$-\Delta \log L$', fontsize=20)
plt.legend(fontsize=16)
plt.tight_layout(pad=0.5)

# %% [markdown]
# ## Scenario III

# %%
fitC1 = pd.read_csv('likelihoodC1.dat')
fitC3 = pd.read_csv('likelihoodC3.dat')
fitbq = pd.read_csv('likelihoodbq.dat')

# %%
plt.plot(fitC1['C1'], -fitC1['global'], c=colors_line[4], label='Global')
plt.plot(fitC1['C1'], -fitC1['likelihood_rd_rds.yaml'], c=colors_line[1], label=r'$b\to c\ell\nu$')
plt.plot(fitC1['C1'], -fitC1['likelihood_bqnunu.yaml'], c=colors_line[3], label=r'$b\to s\nu\bar{\nu}$')
plt.axhline(-np.max(fitC1['global'])+3.53/2, c='k', ls='--')
plt.axvline(-0.105, c='k', ls='--')
plt.axvline(-0.09, c='k', ls='--')
plt.axvline(-0.12, c='k', ls='--')
plt.ylim(-25, 20)
plt.xlim(-0.3, 0)
plt.xlabel(r'$C_1$', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel(r'$-\Delta \log L$', fontsize=20)
plt.legend(fontsize=16)
plt.tight_layout(pad=0.5)
plt.savefig('likelihood_C1.pdf')

# %%
-0.12+0.105
# Out:
# -0.015

# %%
plt.plot(fitC3['C3'], -fitC3['global'], c=colors_line[4], label='Global')
plt.plot(fitC3['C3'], -fitC3['likelihood_rd_rds.yaml'], c=colors_line[1], label=r'$b\to c\ell\nu$')
plt.plot(fitC3['C3'], -fitC3['likelihood_bqnunu.yaml'], c=colors_line[3], label=r'$b\to s\nu\bar{\nu}$')
plt.axhline(-np.max(fitC3['global'])+3.53/2, c='k', ls='--')
plt.axvline(-0.12, c='k', ls='--')
plt.axvline(-0.10, c='k', ls='--')
plt.axvline(-0.13, c='k', ls='--')
plt.xlim(-0.3, 0)
plt.ylim(-25, 20)
plt.xlabel(r'$C_3$', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel(r'$-\Delta \log L$', fontsize=20)
plt.legend(fontsize=16)
plt.tight_layout(pad=0.5)
plt.savefig('likelihood_C3.pdf')

# %%
plt.plot(fitbq['bq'], -fitbq['global'], c=colors_line[4], label='Global')
plt.plot(fitbq['bq'], -fitbq['likelihood_rd_rds.yaml'], c=colors_line[1], label=r'$b\to c\ell\nu$')
plt.plot(fitbq['bq'], -fitbq['likelihood_bqnunu.yaml'], c=colors_line[3], label=r'$b\to s\nu\bar{\nu}$')
plt.axhline(-np.max(fitbq['global'])+3.53/2, c='k', ls='--')
plt.axvline(0.64, c='k', ls='--')
plt.axvline(0.4, c='k', ls='--')
plt.axvline(2.0, c='k', ls='--')
plt.xlim(0,3)
plt.ylim(-25, 20)
plt.xlabel(r'$\beta^q$', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel(r'$-\Delta \log L$', fontsize=20)
plt.legend(fontsize=16)
plt.tight_layout(pad=0.5)
plt.savefig('likelihood_bq.pdf')
